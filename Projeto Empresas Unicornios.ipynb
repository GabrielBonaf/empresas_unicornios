# %% [markdown]
# <a href="https://colab.research.google.com/github/GabrielBonaf/empresas_unicornios/blob/main/Projeto%20Empresas%20Unicornios.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Projeto - Analise de Empresas Unicórnios

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

import warnings
warnings.filterwarnings('ignore')

# %%
base_dados = pd.read_csv('/unicorns at july end  - in july end.csv')

# %%
base_dados.head
# Out:
# <bound method NDFrame.head of                   Empresa Valor ($) Data de Adesão           Pais  \
# 0               ByteDance      $140       4/7/2017          China
# 1                  SpaceX      $127      12/1/2012  United States
# 2                   SHEIN      $100       7/3/2018          China
# 3                  Stripe       $95      1/23/2014  United States
# 4                   Canva       $40       1/8/2018      Australia
# ...                   ...       ...            ...            ...
# 1173          LeadSquared        $1      6/21/2022          India
# 1174            FourKites        $1      6/21/2022  United States
# 1175          VulcanForms        $1       7/5/2022  United States
# 1176          SingleStore        $1      7/12/2022  United States
# 1177  Unstoppable Domains        $1      7/27/2022  United States
#
#               City                                 Setor  \
# 0           Beijing              Artificial intelligence
# ...

# %%
base_dados.columns
# Out:
# Index(['Company', 'Valuation ($B)', 'Date Joined', 'Country', 'City ',
#        'Industry', 'Investors'],
#       dtype='object')

# %%
base_dados.rename( columns={
    'Unnamed: 0' : 'Id',
    'Company' : 'Empresa',
    'Valuation ($B)' : 'Valor ($)',
    'Date Joined' : 'Data de Adesão',
    'Country' : 'Pais',
    'City' : 'Cidade',
    'Industry': 'Setor',
    'Select Investors': 'Investidores',
}, inplace=True )

# %%
base_dados.columns
# Out:
# Index(['Empresa', 'Valor ($)', 'Data de Adesão', 'Pais', 'City ', 'Setor',
#        'Investors'],
#       dtype='object')

# %%
base_dados.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1178 entries, 0 to 1177
# Data columns (total 7 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Empresa         1178 non-null   object
#  1   Valor ($)       1178 non-null   object
#  2   Data de Adesão  1178 non-null   object
#  3   Pais            1178 non-null   object
#  4   City            1178 non-null   object
#  5   Setor           1178 non-null   object
#  6   Investors       1160 non-null   object
# dtypes: object(7)
# memory usage: 64.5+ KB

# %%
base_dados.isnull().sum()
# Out:
# Empresa            0
# Valor ($)          0
# Data de Adesão     0
# Pais               0
# City               0
# Setor              0
# Investors         18
# dtype: int64

# %%
plt.figure( figsize=(15,6) )
plt.title('Analisando Campos Nulos')
sns.heatmap( base_dados.isnull(), cbar=False );

# %%
base_dados.nunique()
# Out:
# Empresa           1175
# Valor ($)          221
# Data de Adesão     689
# Pais                48
# City               286
# Setor               33
# Investors         1144
# dtype: int64

# %%
base_dados['Setor'].unique()
# Out:
# array(['Artificial intelligence', 'Other',
#        'E-commerce & direct-to-consumer', 'Fintech',
#        'Internet software & services',
#        'Supply chain, logistics, & delivery',
#        'Data management & analytics',
#        'Sequoia Capital, Thoma Bravo, Softbank', 'Edtech', 'Hardware',
#        'Consumer & retail', 'Health', 'Auto & transportation',
#        'Cybersecurity', 'Mobile & telecommunications', 'Travel',
#        'Kuang-Chi',
#        'Tiger Global Management, Tiger Brokers, DCM Ventures',
#        'Jungle Ventures, Accel, Venture Highway',
#        'Artificial Intelligence', 'GIC. Apis Partners, Insight Partners',
#        'Vision Plus Capital, GSR Ventures, ZhenFund',
#        'Hopu Investment Management, Boyu Capital, DC Thomson Ventures',
#        '500 Global, Rakuten Ventures, Golden Gate Ventures',
#        'Sequoia Capital China, ING, Alibaba Entrepreneurs Fund',
#        'Sequoia Capital China, Shunwei Capital Partners, Qualgro',
# ...

# %%
base_dados['Setor'].value_counts()
# Out:
# Fintech                                                               237
# Internet software & services                                          222
# E-commerce & direct-to-consumer                                       103
# Health                                                                 93
# Artificial intelligence                                                74
# Supply chain, logistics, & delivery                                    65
# Other                                                                  65
# Cybersecurity                                                          58
# Data management & analytics                                            45
# Auto & transportation                                                  39
# Hardware                                                               38
# Mobile & telecommunications                                            37
# Edtech                                                                 32
# ...

# %%
base_dados['Setor'].value_counts( normalize=True )
# Out:
# Fintech                                                               0.201188
# Internet software & services                                          0.188455
# E-commerce & direct-to-consumer                                       0.087436
# Health                                                                0.078947
# Artificial intelligence                                               0.062818
# Supply chain, logistics, & delivery                                   0.055178
# Other                                                                 0.055178
# Cybersecurity                                                         0.049236
# Data management & analytics                                           0.038200
# Auto & transportation                                                 0.033107
# Hardware                                                              0.032258
# Mobile & telecommunications                                           0.031409
# ...

# %%
plt.figure( figsize=(15,6) )
plt.title('Analise dos Setores')
plt.bar( base_dados['Setor'].value_counts().index, base_dados['Setor'].value_counts()  )
plt.xticks( rotation=45, ha='right' );

# %%
Analise = round( base_dados['Pais'].value_counts( normalize=True ) * 100, 1 )

# %%
# Plot dos Paises
plt.figure( figsize=(20,6) )
plt.title('Analise dos Paises gerador de Unicornios')
plt.pie(
    Analise,
    labels = Analise.index,
    shadow=True,
    startangle=90,
    autopct='%1.1f%%'
);

# %%
# Plot geral dos Paises - TOP 10
plt.figure( figsize=(15,6) )
plt.title('Analise dos Paises gerador de Unicornios - Top 10')
plt.pie(
    Analise.head(10),
    labels = Analise.index[0:10],
    shadow=True,
    startangle=90,
    autopct='%1.1f%%'
);

# %%
# Conversão para Data
base_dados['Data de Adesão'] = pd.to_datetime( base_dados['Data de Adesão'] )

base_dados['Data de Adesão'].head()
# Out:
# 0   2017-04-07
# 1   2012-12-01
# 2   2018-07-03
# 3   2014-01-23
# 4   2018-01-08
# Name: Data de Adesão, dtype: datetime64[ns]

# %%
base_dados['Mes'] = pd.DatetimeIndex( base_dados['Data de Adesão'] ).month
base_dados['Ano'] = pd.DatetimeIndex( base_dados['Data de Adesão'] ).year

base_dados.head()
# Out:
#      Empresa Valor ($) Data de Adesão           Pais          City   \
# 0  ByteDance      $140     2017-04-07          China        Beijing
# 1     SpaceX      $127     2012-12-01  United States      Hawthorne
# 2      SHEIN      $100     2018-07-03          China       Shenzhen
# 3     Stripe       $95     2014-01-23  United States  San Francisco
# 4      Canva       $40     2018-01-08      Australia    Surry Hills
#
#                              Setor  \
# 0          Artificial intelligence
# 1                            Other
# 2  E-commerce & direct-to-consumer
# 3                          Fintech
# 4     Internet software & services
#
#                                            Investors  Mes   Ano
# 0  Sequoia Capital China, SIG Asia Investments, S...    4  2017
# 1  Founders Fund, Draper Fisher Jurvetson, Rothen...   12  2012
# 2  Tiger Global Management, Sequoia Capital China...    7  2018
# 3        Khosla Ventures, LowercaseCapital, capitalG    1  2014
# ...

# %%
base_dados.columns
# Out:
# Index(['Empresa', 'Valor ($)', 'Data de Adesão', 'Pais', 'City ', 'Setor',
#        'Investors', 'Mes', 'Ano'],
#       dtype='object')
